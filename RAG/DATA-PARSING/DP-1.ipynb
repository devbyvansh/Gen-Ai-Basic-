# %%
from langchain_community.document_loaders import (
    TextLoader,
    PyPDFLoader,
    CSVLoader,
    Docx2txtLoader,
    UnstructuredHTMLLoader,
    JSONLoader,
)
print("Execute successfully")
# Out:
# C:\Users\vansh_hxqeh4o\AppData\Local\Temp\ipykernel_16624\2462253573.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import (
# Execute successfully

# %%
#loadingPDF
PypdfLoader = PyPDFLoader(r"D:\GEN AI BASICS\RAG\DATA-PARSING\Data\Sample_Document_For_PDF_Loading.pdf")
docs=PypdfLoader.load()
print("pdf loaded successfully")
# Out:
# pdf loaded successfully

# %%
docs[0]
# Out:
# Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-20T09:02:26+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-07-20T09:02:26+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': 'D:\\GEN AI BASICS\\RAG\\DATA-PARSING\\Data\\Sample_Document_For_PDF_Loading.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Sample PDF Document for Testing PDF Loading\nThis document is intended for testing PDF loading, parsing, and text extraction in applications such\nas LangChain, PyPDFLoader, LlamaIndex, RAG pipelines, and document processing systems.\nSection 1: Introduction\nArtificial Intelligence (AI) enables computers to perform tasks that normally require human\nintelligence. Machine Learning is a subset of AI where models learn patterns from data.\nSection 2: Sample Data\nName: Vansh Khanna\nDepartment: Information Technology\nUniversity: AKTU\nSeme
# ...

# %%
docs[0].metadata
# Out:
# {'producer': 'ReportLab PDF Library - (opensource)',
#  'creator': '(unspecified)',
#  'creationdate': '2026-07-20T09:02:26+00:00',
#  'author': '(anonymous)',
#  'keywords': '',
#  'moddate': '2026-07-20T09:02:26+00:00',
#  'subject': '(unspecified)',
#  'title': '(anonymous)',
#  'trapped': '/False',
#  'source': 'D:\\GEN AI BASICS\\RAG\\DATA-PARSING\\Data\\Sample_Document_For_PDF_Loading.pdf',
#  'total_pages': 1,
#  'page': 0,
#  'page_label': '1'}

# %%
print(docs[0].page_content)
# Out:
# Sample PDF Document for Testing PDF Loading
# This document is intended for testing PDF loading, parsing, and text extraction in applications such
# as LangChain, PyPDFLoader, LlamaIndex, RAG pipelines, and document processing systems.
# Section 1: Introduction
# Artificial Intelligence (AI) enables computers to perform tasks that normally require human
# intelligence. Machine Learning is a subset of AI where models learn patterns from data.
# Section 2: Sample Data
# Name: Vansh Khanna
# Department: Information Technology
# University: AKTU
# Semester: 5th
# Skills: Python, Machine Learning, Deep Learning, NLP, Data Science
# Section 3: Technologies
# Python, Pandas, NumPy, Scikit-learn, TensorFlow, PyTorch, LangChain, FAISS, ChromaDB,
# Streamlit, FastAPI.
# Section 4: Conclusion
# This PDF contains headings, paragraphs, and structured text suitable for testing document loaders,
# text chunking, embeddings, vector databases, and retrieval pipelines.

# %%
#Loading Text file
textloader = TextLoader(r"D:\GEN AI BASICS\RAG\DATA-PARSING\Data\Sample_Text_File.txt")
documents = textloader.load()

# %%
print(documents[0].page_content)
# Out:
# Artificial Intelligence (AI) is transforming the way people interact with technology. It enables computers to perform tasks such as language understanding, image recognition, and decision-making.
# Machine Learning (ML) is a branch of AI that allows computers to learn from data without being explicitly programmed. ML models identify patterns in historical data and use them to make predictions or decisions.
# Natural Language Processing (NLP) is a field of AI that focuses on enabling computers to understand, interpret, and generate human language. Applications of NLP include chatbots, language translation, sentiment analysis, and text summarization.
# Deep Learning is a specialized area of Machine Learning that uses artificial neural networks with multiple layers. It has achieved remarkable success in computer vision, speech recognition, and generative AI applications.
# ...

# %%
documents[0].metadata
# Out:
# {'source': 'D:\\GEN AI BASICS\\RAG\\DATA-PARSING\\Data\\Sample_Text_File.txt'}

# %% [markdown]
# WHAT IS META DATA?
# ->Metadata is "data about data." It provides additional
# information that describes a file, document,
#  image, audio, video, or any other piece of data

# %%
#Loading CSV file
csvloader =CSVLoader(r"D:\GEN AI BASICS\RAG\DATA-PARSING\Data\random_employee_data.csv")
csvdocs = csvloader.load()

# %%
csvdocs[0].metadata
# Out:
# {'source': 'D:\\GEN AI BASICS\\RAG\\DATA-PARSING\\Data\\random_employee_data.csv',
#  'row': 0}

# %%
print(csvdocs[0].page_content)
# Out:
# Employee_ID: EMP1001
# First_Name: Alice
# Last_Name: Anderson
# Age: 32
# Department: Sales
# City: New York
# Salary_USD: 110325
# Experience_Years: 5
# Performance_Rating: 4.9

# %%
#json file loading
from langchain_community.document_loaders import JSONLoader
loader = JSONLoader(
    file_path=r"D:\GEN AI BASICS\RAG\DATA-PARSING\Data\sample_products.json",
    jq_schema=".products[]",
    text_content=False
)
jsondocs = loader.load()

# %%
jsondocs[0].metadata
# Out:
# {'source': 'D:\\GEN AI BASICS\\RAG\\DATA-PARSING\\Data\\sample_products.json',
#  'seq_num': 1}

# %%
print(jsondocs[0].page_content)
# Out:
# {"product_id": "P001", "name": "Product 1", "category": "Electronics", "price": 162.6, "in_stock": false, "rating": 4.4, "tags": ["popular", "discount"]}

# %%
#html file loading
html_parser = UnstructuredHTMLLoader("D:\\GEN AI BASICS\\RAG\\DATA-PARSING\\Data\\sample_page.html")
html_docs = html_parser.load()

# %%
html_docs[0].metadata
# Out:
# {'source': 'D:\\GEN AI BASICS\\RAG\\DATA-PARSING\\Data\\sample_page.html'}

# %%
html_docs[0].page_content
# Out:
# 'Sample HTML Page\n\nThis page is designed for practicing HTML parsing, web scraping, BeautifulSoup, and LangChain HTML loaders.\n\nFeatures\n\nHeadings\n\nParagraphs\n\nLists\n\nTables\n\nLinks\n\nProducts\n\nID Name Category 101 Wireless Mouse Electronics 102 Notebook Stationery 103 Water Bottle Home\n\nVisit Example Website.\n\nCopyright © 2026 Sample Company'

# %%
#docx file loading
from langchain_community.document_loaders import Docx2txtLoader
docx_loader = Docx2txtLoader(r"D:\GEN AI BASICS\RAG\DATA-PARSING\Data\sample_document.docx")
docx_docs = docx_loader.load()

# %%
docx_docs[0].metadata
# Out:
# {'source': 'D:\\GEN AI BASICS\\RAG\\DATA-PARSING\\Data\\sample_document.docx'}

# %%
print(docx_docs[0].page_content)
# Out:
# Sample DOCX Document
#
# This is a sample Microsoft Word document created for testing DOCX loading and parsing with LangChain's Docx2txtLoader or UnstructuredWordDocumentLoader.
#
# Introduction
#
# Artificial Intelligence enables machines to perform tasks that typically require human intelligence, such as reasoning, learning, and decision making.
#
# Technologies
#
# Python
#
# Machine Learning
#
# Deep Learning
#
# Natural Language Processing
#
# LangChain
#
# Vector Databases
#
# Sample Table
#
# ID
#
# Course
#
# Duration
#
# 101
#
# Python Basics
#
# 4 Weeks
#
# 102
#
# Machine Learning
#
# 8 Weeks
#
# 103
#
# Generative AI
#
# 6 Weeks
#
# Conclusion
#
# This document contains headings, paragraphs, bullet lists, and a table, making it suitable for testing DOCX parsing, chunking, and RAG pipelines.

# %%
#loading web page
from langchain_community.document_loaders import WebBaseLoader
webloader=WebBaseLoader("https://www.geeksforgeeks.org/python-programming-language/")
webdocs=webloader.load()
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
webdocs[0].metadata
# Out:
# {'source': 'https://www.geeksforgeeks.org/python-programming-language/',
#  'title': 'Python Tutorial - GeeksforGeeks',
#  'description': 'Your All-in-One Learning Portal: GeeksforGeeks is a comprehensive educational platform that empowers learners across domains-spanning computer science and programming, school education, upskilling, commerce, software tools, competitive exams, and more.',
#  'language': 'en'}

# %%
print(webdocs[0].page_content)
# Out:
# Python Tutorial - GeeksforGeeksCoursesTutorialsPracticeJobsPython TutorialData TypesInterview QuestionsExamplesQuizzesDSA PythonData ScienceNumPyPandasPracticeDjangoFlaskShare Your ExperiencesPython FundamentalsIntroductionInput & OutputVariablesOperatorsKeywordsData TypesConditional StatementsLoopsFunctionsPython Data StructuresStringListTuplesDictionarySetArraysAdvanced PythonOOP ConceptsException HandlingFile HandlingPython DatabaseMongoDBMySQLPackagesModulesDSA LibrariesPython GUIData Science with PythonNumpyPandasMatplotlibSeabornStatsModelModel BuildingTensorFlowPyTorchWeb Development with PythonFlaskDjangoDjango ORMJinja2 TemplatingDjango TemplatesREST APIBuild API with DRFPython PracticeQuizPractice ProblemsInterview Q & ACoursesPlacement 360 CourseData Analytics CourseDSA and System DesignSummer SkillUpExplorePython TutorialLast Updated : 14 Jul, 2026Python is one of the most popular programming languages. It’s simple to use, packed with features and supported by a wide rang
# ...
